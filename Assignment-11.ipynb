# %% [markdown]
# Q1. What is the concept of a metaclass?
#
# Ans->

# %% [markdown]
# Metaclass in python is a class of a class that define how a class behaves.A class is itself a instance of Metaclass and any instance of class in python is a instance of type metaclass.
#
# E.g. Type of int,str,list,tuple and many more is of metaclass type.

# %% [markdown]
# Q2. What is the best way to declare a class's metaclass?
#
# Ans->

# %%
class meta(type):
    pass
class class_meta(metaclass = meta):
    pass
print(type(meta))
print(type(class_meta))
# Out:
# <class 'type'>
# <class '__main__.meta'>

# %% [markdown]
# Q3. How do class decorators overlap with metaclasses for handling classes ?
#
# Ans->

# %% [markdown]
# Anything you can do with a class decorator, you can of course do with a custom metaclasses (just apply the functionality of the "decorator function", i.e., the one that takes a class object and modifies it, in the course of the metaclass's __new__ or __init__ that make the class object!).

# %% [markdown]
# Q4. How do class decorators overlap with metaclasses for handling instances?
#
# Ans->

# %% [markdown]
# Anything you can do with a class decorator, you can of course do with a custom metaclass (just apply the functionality of the "decorator function", i.e., the one that takes a class object and modifies it, in the course of the metaclass's __new__ or __init__ that make the class object!).
